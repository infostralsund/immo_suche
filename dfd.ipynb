# %%
import pandas as pd
import json

# %%
df = pd.read_excel('smaller.xls')

# %%
df.keys()
df.head()
# Out:
#   Objekt_Anschriften
# 0            Strasse
# 1    Wilhelmstraße 3
# 2    Wilhelmstraße 3
# 3       Seestraße 16
# 4        Pappelweg 4

# %%
type(df["Objekt_Anschriften"][3])
# Out:
# str

# %%
count = df["Objekt_Anschriften"].value_counts() 
ordered = count.sort_values(ascending=False, inplace=True)
ordered

# %%
unique_elements = df["Objekt_Anschriften"].unique()
unique_elements = list(unique_elements)
type(unique_elements)
# Out:
# list

# %%
image_di = count.plot(kind='bar', stacked=True, figsize=(10, 10))
type(image_di)
# Out:
# matplotlib.axes._axes.Axes

# %%
type(image_di)
# Out:
# matplotlib.axes._axes.Axes

# %%
count.plot(kind='hist', stacked=True, figsize=(10, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %%
for i in unique_elements:
    count = df.groupby([i]).count()

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 1 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Objekt_Anschriften  306 non-null    object
# dtypes: object(1)
# memory usage: 2.5+ KB

# %%
df.iloc[2]
# Out:
# Objekt_Anschriften    Wilhelmstraße 3
# Name: 2, dtype: object

# %%
df.columns
# Out:
# Index(['Objekt_Anschriften'], dtype='object')

# %% [markdown]
# # Change the datatype of the column

# %%
#df["Objekt_Anschriften"] = df["Objekt_Anschriften"].astype()

# %%
df.describe()
# Out:
#        Objekt_Anschriften
# count                 306
# unique                273
# top       Wilhelmstraße 3
# freq                    6

# %%
jsondata = df.to_json()
parsed_json = json.loads(jsondata)
print(json.dumps(parsed_json, indent=4, sort_keys=True))

# %%
pd.options.plotting.backend = "plotly"
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\info\Videos\code_entwicklung\dfd.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/info/Videos/code_entwicklung/dfd.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> pd.options.plotting.backend = "plotly"
#
# File c:\Users\info\Videos\code_entwicklung\kawohlenv\Lib\site-packages\pandas\_config\config.py:235, in DictWrapper.__setattr__(self, key, val)
#     232 # you can't set new keys
#     233 # can you can't overwrite subtrees
#     234 if key in self.d and not isinstance(self.d[key], dict):
# --> 235     _set_option(prefix, val)
#     236 else:
#     237     raise OptionError("You can only set the value of existing options")
#
# File c:\Users\info\Videos\code_entwicklung\kawohlenv\Lib\site-packages\pandas\_config\config.py:171, in _set_option(*args, **kwargs)
#     169 o = _get_registered_option(key)
# ...
